# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# Create an array to graph
data = np.random.randn(50)
plt.style.use('classic')

# %%
plt.plot(data)

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
# Grab default style
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
plt.style.use('seaborn-darkgrid')

# %%
plt.plot(data)

# %%
plt.close
# Out:
# <function matplotlib.pyplot.close(fig=None)>

# %%
# create a new figure

fig = plt.figure()
ax = plt.axes()

ax.plot(data)

# %%
plt.plot(data, color='#FFDD44')

# %%
plt.plot(data, linestyle='dashed')

# %%
plt.plot(data, linewidth= 2)

# %%
# https://matplotlib.org/api/markers_api.html
plt.plot(data, marker='.')

# %%
plt.plot(data, marker='.', linestyle='dashed', dash_capstyle='round')

# %%
plt.plot(data, marker='.', linestyle='-', solid_joinstyle='bevel')
