# %%
import pandas as pd

# %%
# !pwd
# Out:
# /Users/joshua/Development/business-analysis/Examples

# %%
# !ls ../Data
# Out:
#  customer_data.xlsx	       sales_data_sample.xlsx
#  part_usage_trailing_12.xlsx   sales_data_sample_no_customer.xlsx
#  sales_data_sample.csv	      '~$part_usage_trailing_12.xlsx'

# %%
xlsx = pd.ExcelFile('../Data/part_usage_trailing_12.xlsx')

# %%
sheets = xlsx.sheet_names
sheets
# Out:
# ['AMD-SYR', 'MX-ISE']

# %%
plant_1 = pd.read_excel(xlsx,sheets[0])
plant_2 = pd.read_excel(xlsx,sheets[1])

# %%
plant_1.head()
# Out:
#     Family Part Number                          Desc  2017-05  2017-06  \
# 0  AMD-SYR       H-032       SCREW HEX 8-32 X .50 TT  63333.0  62669.0
# 1  AMD-SYR       H-013                         SCREW  38496.0  37168.0
# 2  AMD-SYR       H-040  SCREW FLAT 5/16-18 X .875 TT  35148.0  34232.0
# 3  AMD-SYR       H-087          COPPER TUBING (LEAD)  33368.0  33149.0
# 4  AMD-SYR       H-012    SCREW, HEX, 5/16-18 X 1 TT  31972.0  32896.0
#
#    2017-07  2017-08  2017-09  2017-10  2017-11     ...       2018-04  2018-05  \
# 0  49093.0  67015.0  63097.0  54899.0  56857.0     ...       60193.0  66494.0
# 1  28601.0  40619.0  37274.0  33038.0  34226.0     ...       37369.0  38903.0
# 2  30600.0  40980.0  39813.0  34332.0  36040.0     ...       32128.0  42520.0
# 3  22733.0  35541.0  36186.0  29655.0  31884.0     ...       30680.0  36258.0
# 4  24300.0  28252.0  31560.0  27376.0  28532.0     ...       29116.0  29332.0
#
# ...

# %%
plant_2.head()
# Out:
#    Family Part Number                                               Desc  \
# 0  MX-ISE     RVT1419        RIVET 1/8 X 1/2 DOME HEAD, BREAK-STEM STEEL
# 1  MX-ISE     INS0128   SCREW INSULATOR, NYLON (RIVET INSULATOR) #6X3/16
# 2  MX-ISE     BLT3168  1/4-28X1.25 SOCKET HEAD CAP SCREW, ZINC-PLATED...
# 3  MX-ISE     WSH0239  WASHER #10 SPLIT-RING LOCK, ZINC-PLATED (ANSI/...
# 4  MX-ISE     SCR1638                                10-32X.5 MACH SCREW
#
#    2017-05  2017-06  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0  15008.0  14272.0  13472.0  13168.0  11200.0  18280.0   9928.0
# 1  15008.0  14272.0  13472.0  13168.0  11200.0  18280.0   9928.0
# 2   5412.0   6288.0   3654.0   9270.0  10752.0   4362.0  14868.0
# 3   7706.0   7476.0   6826.0   6710.0   5794.0   9480.0   5214.0
# 4   7504.0   7136.0   6736.0   6584.0   5600.0   9140.0   4964.0
#
#        ...        2018-03  2018-04  2018-05  2018-06  2018-07  2018-08  \
# ...

# %%
usage = plant_1.merge(plant_2, how='outer', on='Part Number')

# %%
usage.columns
# Out:
# Index(['Family_x', 'Part Number', 'Desc_x', '2017-05_x', '2017-06_x',
#        '2017-07_x', '2017-08_x', '2017-09_x', '2017-10_x', '2017-11_x',
#        '2017-12_x', '2018-01_x', '2018-02_x', '2018-03_x', '2018-04_x',
#        '2018-05_x', '2018-06_x', '2018-07_x', '2018-08_x', '2018-09_x',
#        '2018-10_x', 'Grand Total_x', 'Average Month_x', 'Unnamed: 23',
#        'Family_y', 'Desc_y', '2017-05_y', '2017-06_y', '2017-07_y',
#        '2017-08_y', '2017-09_y', '2017-10_y', '2017-11_y', '2017-12_y',
#        '2018-01_y', '2018-02_y', '2018-03_y', '2018-04_y', '2018-05_y',
#        '2018-06_y', '2018-07_y', '2018-08_y', '2018-09_y', '2018-10_y',
#        'Grand Total_y', 'Average Month_y'],
#       dtype='object')

# %%
usage.head()
# Out:
#   Family_x Part Number                        Desc_x  2017-05_x  2017-06_x  \
# 0  AMD-SYR       H-032       SCREW HEX 8-32 X .50 TT    63333.0    62669.0
# 1  AMD-SYR       H-013                         SCREW    38496.0    37168.0
# 2  AMD-SYR       H-040  SCREW FLAT 5/16-18 X .875 TT    35148.0    34232.0
# 3  AMD-SYR       H-087          COPPER TUBING (LEAD)    33368.0    33149.0
# 4  AMD-SYR       H-012    SCREW, HEX, 5/16-18 X 1 TT    31972.0    32896.0
#
#    2017-07_x  2017-08_x  2017-09_x  2017-10_x  2017-11_x       ...         \
# 0    49093.0    67015.0    63097.0    54899.0    56857.0       ...
# 1    28601.0    40619.0    37274.0    33038.0    34226.0       ...
# 2    30600.0    40980.0    39813.0    34332.0    36040.0       ...
# 3    22733.0    35541.0    36186.0    29655.0    31884.0       ...
# 4    24300.0    28252.0    31560.0    27376.0    28532.0       ...
#
#    2018-03_y  2018-04_y  2018-05_y  2018-06_y  2018-07_y  2018-08_y  \
# ...
