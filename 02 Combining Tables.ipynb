# %%
import pandas as pd
import numpy as np

# %%
# %cd /Users/joshua/Development/business-analysis/Data
# !ls
# Out:
# /Users/joshua/Development/business-analysis/Data
#  customer_data.xlsx	  sales_data_sample_no_customer.xlsx
#  sales_data_sample.csv	 '~$sales_data_sample_no_customer.xlsx'
#  sales_data_sample.xlsx

# %%
orders = pd.read_excel('sales_data_sample_no_customer.xlsx')
customers = pd.read_excel('customer_data.xlsx')

# %%
orders.head()
# Out:
#    ORDERNUMBER  CUSTOMERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0        10107            5806               30      95.70                2
# 1        10121            5398               34      81.35                5
# 2        10134            3504               41      94.74                2
# 3        10145            5461               45      83.26                6
# 4        10159             378               49     100.00               14
#
#      SALES  ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0  2871.00 2003-02-24  Shipped       1         2     2003  Motorcycles    95
# 1  2765.90 2003-05-07  Shipped       2         5     2003  Motorcycles    95
# 2  3884.34 2003-07-01  Shipped       3         7     2003  Motorcycles    95
# 3  3746.70 2003-08-25  Shipped       3         8     2003  Motorcycles    95
# 4  5205.27 2003-10-10  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE
# 0    S10_1678
# 1    S10_1678
# ...

# %%
customers.head()
# Out:
#    CUSTOMERNUMBER              CUSTOMERNAME             PHONE  \
# 0            5806         Land of Toys Inc.        2125557818
# 1            5398        Reims Collectables        26.47.1555
# 2            3504           Lyon Souveniers  +33 1 46 62 7555
# 3            5461         Toys4GrownUps.com        6265557265
# 4             378  Corporate Gift Ideas Co.        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue          NaN            NYC    NY      10022
# 1             59 rue de l'Abbaye          NaN          Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia          NaN          Paris   NaN      75508
# 3             78934 Hillside Dr.          NaN       Pasadena    CA      90003
# 4                7734 Strong St.          NaN  San Francisco    CA        NaN
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME
# 0     USA       NaN              Yu             Kwai
# ...

# %%
orders.shape
# Out:
# (2823, 14)

# %%
customers.shape
# Out:
# (92, 12)

# %%
combined_sales_data = orders.merge(customers, how='left')
combined_sales_data.head()
# Out:
#    ORDERNUMBER  CUSTOMERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  \
# 0        10107            5806               30      95.70                2
# 1        10121            5398               34      81.35                5
# 2        10134            3504               41      94.74                2
# 3        10134            3504               41      94.74                2
# 4        10145            5461               45      83.26                6
#
#      SALES  ORDERDATE   STATUS  QTR_ID  MONTH_ID       ...         \
# 0  2871.00 2003-02-24  Shipped       1         2       ...
# 1  2765.90 2003-05-07  Shipped       2         5       ...
# 2  3884.34 2003-07-01  Shipped       3         7       ...
# 3  3884.34 2003-07-01  Shipped       3         7       ...
# 4  3746.70 2003-08-25  Shipped       3         8       ...
#
#               PHONE                   ADDRESSLINE1  ADDRESSLINE2      CITY  \
# ...

# %%
order_data = combined_sales_data[['ORDERNUMBER','CUSTOMERNUMBER','CUSTOMERNAME']].copy()

# %%
order_data.head()
# Out:
#    ORDERNUMBER  CUSTOMERNUMBER        CUSTOMERNAME
# 0        10107            5806   Land of Toys Inc.
# 1        10121            5398  Reims Collectables
# 2        10134            3504     Lyon Souveniers
# 3        10134            3504   Gifts4AllAges.com
# 4        10145            5461   Toys4GrownUps.com
