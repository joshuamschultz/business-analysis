# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
po_mast = pd.ExcelFile('/Users/joshua/Chess Files/Databases/pomast.xlsx')
po_mast

# %%
po_mast.sheet_names
# Out:
# ['pomast']

# %%
df = po_mast.parse('pomast')
df.head()
# Out:
#     purno  vendno                   company    puramt    recamt  freight  \
# 0  013038  234500                VANTAGE IC  13750.00  13750.00      0.0
# 1  122073   13800      STAR STAINLESS SCREW    232.05    232.05      0.0
# 2  013041   10705            N D INDUSTRIES    237.36    237.36      0.0
# 3  013021   13800      STAR STAINLESS SCREW    780.58    780.58      0.0
# 4  013045   13400  STANDARD HORSE NAIL CORP    158.03    158.03      0.0
#
#    prtid potype postat  pcustno   ...                        comment2  \
# 0    NaN      O      S      NaN   ...                             NaN
# 1    NaN      O      S      NaN   ...    PLEASE SHIP UPS GROUND ASAP!
# 2    NaN      O      S      NaN   ...              5 THREADS MINIMUM!
# 3    NaN      O      S      NaN   ...               PLEASE SHIP ASAP!
# 4    NaN      O      S      NaN   ...    PLEASE SHIP UPS GROUND ASAP!
#
#      comment3 comment4 final  type cpono  rtd cponum return_num  check2
# ...

# %%
_ = plt.hist(df['puramt'])
_ = plt.xlabel('Order Amount')
_ = plt.ylabel('Count')
plt.show()

# %%
plt.gcf().clear()
sns.set()
bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 1000, 10000, 100000]
_ = plt.hist(df['puramt'], bins=bins)
_ = plt.xlabel('Order Amount')
_ = plt.ylabel('Count')
plt.show()

# %%
plt.gcf().clear()
_ = plt.hist(df['puramt'], bins=100)
_ = plt.xlabel('Order Amount')
_ = plt.ylabel('Count')
plt.show()

# %%
plt.gcf().clear()
df_adjusted = df[(df['puramt'] >= 0)         & (df['puramt']        <= 10000)]
_ = plt.hist(df_adjusted['puramt'], bins=50)
_ = plt.xlabel('Order Amount')
_ = plt.ylabel('Count')
plt.show()

# %%
plt.gcf().clear()
df_adjusted = df[(df['puramt'] >= 0) & (df['puramt'] <= 1000)]
_ = plt.hist(df_adjusted['puramt'], bins=50)
_ = plt.xlabel('Order Amount')
_ = plt.ylabel('Count')
plt.show()

# %%
plt.gcf().clear()
_ = sns.swarmplot(x='company', y='puramt', data=df_adjusted)
_ = plt.xlabel('Vendor')
_ = plt.ylabel('Spend')
plt.show()

# %%
plt.gcf().clear()
max_purchase = 10000
vendor = ['STAR STAINLESS SCREW', 'N D INDUSTRIES']
df_adjusted = df[(df['puramt'] >= 0) & (df['puramt'] <= max_purchase)]
df_adjusted_vendor = df_adjusted.loc[df['company'].isin(vendor)]
_ = sns.swarmplot(x='company', y='puramt', data=df_adjusted_vendor)
_ = plt.xlabel('Vendor')
_ = plt.ylabel('Spend')
plt.show()

# %%
plt.gcf().clear()
vendor = ['STAR STAINLESS SCREW']
df_adjusted_vendor = df_adjusted.loc[df['company'].isin(vendor)]
x = np.sort(df_adjusted_vendor['puramt'])
y = np.arange(1, len(x)+1) / len(x)
_ = plt.plot(x, y, marker='.', linestyle='none')
_ = plt.xlabel('Purchase Ammount')
_ = plt.ylabel('ECDF')
plt.margins(0.02)
plt.show()
